# %% [markdown]
# # Stacked LSTMs with Memory Between Batches
# # Stacked LSTM for international airline passengers problem with memory

# %% [markdown]
# ## Load packages

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# Out:
# 2024-03-04 08:18:16.436420: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Define a function to convert an array of values into a dataset matrix

# %%
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

# %% [markdown]
# ## load the dataset

# %%
fnam='https://raw.githubusercontent.com/SiuSunChun/2024LearningLSTM/main/airline-passengers.csv?raw=true'
dataframe = read_csv(fnam, usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')

# %% [markdown]
# ## Look at the data

# %%
plt.plot(dataset)
plt.show()

# %% [markdown]
# ## Preprocess the data to be model input

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# reshape into X=t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %% [markdown]
# ## Set up and fit the LSTM model

# %%
# create and fit the LSTM network
batch_size = 1
model = Sequential()
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True, return_sequences=True))
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
# Fix random seed for reproducibility
tf.random.set_seed(20240304)
for i in range(100):
	model.fit(trainX, trainY, epochs=1, batch_size=batch_size, verbose=2, shuffle=False)
	model.reset_states()
# Out:
# 2024-03-04 08:18:23.602955: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 92/92 - 3s - loss: 0.0051 - 3s/epoch - 28ms/step
# 92/92 - 0s - loss: 0.0306 - 459ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0170 - 450ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0112 - 477ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0073 - 455ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0058 - 453ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0060 - 462ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0060 - 437ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0059 - 434ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0059 - 456ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0058 - 425ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0058 - 444ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0058 - 445ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0058 - 458ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0057 - 456ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0057 - 482ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0057 - 410ms/epoch - 4ms/step
# 92/92 - 0s - loss: 0.0057 - 415ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0056 - 440ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0056 - 458ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0056 - 445ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0056 - 415ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0056 - 422ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0055 - 420ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0055 - 414ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0055 - 416ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0055 - 464ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0054 - 477ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0054 - 428ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0054 - 447ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0053 - 435ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0053 - 433ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0053 - 415ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0052 - 412ms/epoch - 4ms/step
# 92/92 - 0s - loss: 0.0052 - 454ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0051 - 425ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0051 - 439ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0050 - 428ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0050 - 420ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0049 - 434ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0048 - 416ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0047 - 428ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0046 - 415ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0045 - 449ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0044 - 437ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0043 - 425ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0041 - 440ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0040 - 440ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0060 - 446ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0080 - 471ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0055 - 436ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0049 - 466ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0048 - 422ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0043 - 430ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0047 - 397ms/epoch - 4ms/step
# 92/92 - 0s - loss: 0.0042 - 411ms/epoch - 4ms/step
# 92/92 - 0s - loss: 0.0053 - 422ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0046 - 407ms/epoch - 4ms/step
# 92/92 - 0s - loss: 0.0040 - 406ms/epoch - 4ms/step
# 92/92 - 0s - loss: 0.0044 - 430ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0043 - 412ms/epoch - 4ms/step
# 92/92 - 0s - loss: 0.0050 - 446ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0044 - 440ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0039 - 434ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0038 - 444ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0037 - 440ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0041 - 422ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0036 - 439ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0033 - 427ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0038 - 440ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0044 - 418ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0035 - 431ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0035 - 447ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0033 - 447ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0027 - 468ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0033 - 466ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0042 - 449ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0037 - 448ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0049 - 480ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0051 - 429ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0038 - 467ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0033 - 458ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0029 - 487ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0027 - 434ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0026 - 459ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0032 - 465ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0028 - 454ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0024 - 455ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0022 - 462ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0021 - 454ms/epoch - 5ms/step
# 92/92 - 1s - loss: 0.0021 - 502ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0020 - 468ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0020 - 486ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0021 - 439ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0029 - 469ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0049 - 430ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0054 - 468ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0032 - 466ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0027 - 463ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0023 - 451ms/epoch - 5ms/step

# %% [markdown]
# ## Evaluate performance

# %%
# make predictions
trainPredict = model.predict(trainX, batch_size=batch_size)
model.reset_states()
testPredict = model.predict(testX, batch_size=batch_size)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 92/92 [==============================] - 1s 2ms/step
# 44/44 [==============================] - 0s 2ms/step
# Train Score: 24.85 RMSE
# Test Score: 68.81 RMSE

# %% [markdown]
# ## Plot the evaluation results

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
