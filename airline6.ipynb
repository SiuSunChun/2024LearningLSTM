# %% [markdown]
# # Stacked LSTMs with Memory Between Batches
# # Stacked LSTM for international airline passengers problem with memory

# %% [markdown]
# ## Load packages

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# Out:
# 2024-03-04 07:49:51.089358: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Define a function to convert an array of values into a dataset matrix

# %%
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

# %% [markdown]
# ## load the dataset

# %%
dataframe = read_csv('airline-passengers.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')

# %% [markdown]
# ## Look at the data

# %%
plt.plot(dataset)
plt.show()

# %% [markdown]
# ## Preprocess the data to be model input

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# reshape into X=t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %% [markdown]
# ## Set up and fit the LSTM model

# %%
# create and fit the LSTM network
batch_size = 1
model = Sequential()
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True, return_sequences=True))
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
# Fix random seed for reproducibility
tf.random.set_seed(20240304)
for i in range(100):
	model.fit(trainX, trainY, epochs=1, batch_size=batch_size, verbose=2, shuffle=False)
	model.reset_states()
# Out:
# 2024-03-04 07:49:58.149122: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 92/92 - 2s - loss: 0.0052 - 2s/epoch - 26ms/step
# 92/92 - 0s - loss: 0.0147 - 464ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0116 - 433ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0097 - 461ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0085 - 445ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0078 - 424ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0073 - 444ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0070 - 456ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0068 - 438ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0066 - 445ms/epoch - 5ms/step
# 92/92 - 1s - loss: 0.0064 - 516ms/epoch - 6ms/step
# 92/92 - 0s - loss: 0.0062 - 430ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0060 - 416ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0058 - 460ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0055 - 462ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0052 - 440ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0050 - 447ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0048 - 438ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0048 - 429ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0049 - 450ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0050 - 433ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0051 - 472ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0055 - 434ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0058 - 446ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0057 - 438ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0055 - 455ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0056 - 441ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0057 - 460ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0054 - 430ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0049 - 445ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0048 - 442ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0048 - 469ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0049 - 440ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0050 - 450ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0049 - 461ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0049 - 478ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0047 - 448ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0046 - 462ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0044 - 462ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0043 - 454ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0041 - 458ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0039 - 472ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0037 - 459ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0034 - 440ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0034 - 453ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0091 - 481ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0047 - 438ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0035 - 461ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0052 - 480ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0056 - 427ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0042 - 441ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0039 - 444ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0039 - 446ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0039 - 450ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0039 - 449ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0038 - 461ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0037 - 453ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0036 - 468ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0035 - 466ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0034 - 459ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0033 - 469ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0032 - 464ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0031 - 461ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0030 - 457ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0030 - 475ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0029 - 468ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0029 - 442ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0028 - 480ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0028 - 453ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0028 - 468ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0027 - 451ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0027 - 478ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0027 - 453ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0027 - 458ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0026 - 413ms/epoch - 4ms/step
# 92/92 - 0s - loss: 0.0026 - 434ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0026 - 460ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0026 - 433ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0025 - 479ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0025 - 461ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0025 - 459ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0025 - 446ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0025 - 428ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0025 - 453ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0024 - 415ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0024 - 438ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0024 - 460ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0024 - 472ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0024 - 449ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0024 - 472ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0023 - 452ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0023 - 440ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0023 - 433ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0023 - 487ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0023 - 469ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0023 - 451ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0022 - 444ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0022 - 467ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0022 - 489ms/epoch - 5ms/step
# 92/92 - 0s - loss: 0.0022 - 456ms/epoch - 5ms/step

# %% [markdown]
# ## Evaluate performance

# %%
# make predictions
trainPredict = model.predict(trainX, batch_size=batch_size)
model.reset_states()
testPredict = model.predict(testX, batch_size=batch_size)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 92/92 [==============================] - 1s 2ms/step
# 44/44 [==============================] - 0s 2ms/step
# Train Score: 24.71 RMSE
# Test Score: 196.28 RMSE

# %% [markdown]
# ## Plot the evaluation results

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
